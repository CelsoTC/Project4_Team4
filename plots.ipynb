# %%
import numpy as np
import matplotlib.pyplot as plt

test =  np.load('./reward.npy')

plt.plot(test)
plt.xlabel('Epochs')
plt.ylabel('Average reward for the ppast 30 episodes')
plt.title('Initial training - 10,000 epochs, 2 episodes per epoch')
# Out:
# Text(0.5, 1.0, 'Initial training - 10,000 epochs, 2 episodes per epoch')
