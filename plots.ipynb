# %%
import numpy as np
import matplotlib.pyplot as plt

reward =  np.load('./reward.npy')
#maximum_state = np.load('./max_value.npy')

plt.plot(reward)
plt.xlabel('Episodes')
plt.ylabel('Average Reward - Past 30 episodes')
plt.title('Reward vs episodes')
# Out:
# Text(0.5, 1.0, 'Reward vs episodes')
